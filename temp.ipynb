# %%
from dataset import Sacarsm
import json
import os

# %%
data = Sacarsm(mode='train', text_name='data')
data.__len__

# %%
path = r'F:\\DSC_B_2024\\data\text_data\\train.json'
with open(path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
WORKING_PATH='F:\DSC_B_2024\data\text_data'

f1=open(os.path.join(r'F:\DSC_B_2024\data', r'text_data', r'train'+'.json'),'r', encoding='utf-8')
dict_datas = json.load(f1)

# %%
dict_datas
# Out:
# {'0': {'image': '8ae451edcd8ebf697f8763ece249115813149c55733bf8306b971210d48b15d3.jpg',
#   'caption': 'Cô ấy trên mạng vs cô ấy ngoài đời =)))',
#   'label': 'multi-sarcasm'},
#  '1': {'image': '35370ffd6c791d6f8c4ab3dd4363ed468fab41e4824ee9984169f58be672a0b7.jpg',
#   'caption': 'Người tâm linh giao tiếp với người thực tế :)))',
#   'label': 'not-sarcasm'},
#  '2': {'image': '316fdd1477725b9fb1a55015ac06b68b92b50bd4303e08590dadedace629ae61.jpg',
#   'caption': 'Hình như Trăng hôm nay đẹp quá mọi người ạ! 😃 😃\n#canhco',
#   'label': 'multi-sarcasm'},
#  '3': {'image': '8a0f34e0e30e4e5cfb306933c1d25fa801a5da78646b59ca90a3a3c081cdb16c.jpg',
# ...
